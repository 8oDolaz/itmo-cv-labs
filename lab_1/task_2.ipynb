# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
bar_code = cv.imread('code.png')
bar_code = cv.cvtColor(bar_code, cv.COLOR_BGR2GRAY)

# %%
profile = bar_code[bar_code.shape[0] // 2]

plt.plot(profile, color='black')
plt.show()
